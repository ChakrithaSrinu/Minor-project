.001324529992416501, 0.0015098238363862038, 0.0004781019815709442, -0.0008999518468044698, -0.0014556042151525617, -0.0003440248838160187, 0.0004790091479662806, -0.000882002932485193, -0.002357927616685629, -0.0026017690543085337, -0.003040595445781946, -0.0019783899188041687, -0.0006158081814646721, -0.001441290369257331, -0.0021535567939281464, -0.0012391074560582638, 0.0014297195011749864, -0.0012463477905839682, 0.002792725106701255, 0.0005113311344757676, -0.00241410662420094, 0.003144599497318268, 0.0025437374133616686, 0.0018310940358787775, -0.0022829484660178423, 0.0019408928928896785, 0.00133636430837214, 0.0017284564673900604, 0.0014186338521540165, 0.0006465848418883979, -0.001056720851920545, 0.0027846149168908596, 0.0032040600199252367, 0.0012642010115087032, -0.0009456650586798787, 2.3758411771268584e-06, 0.0004062727966811508, -0.0028194414917379618, -0.002741314936429262, -7.700522837694734e-05, 0.0004124291881453246, -0.0019144602119922638, -0.001575091271661222, -0.0024486915208399296, 0.002776205074042082, 4.0432612877339125e-05, -0.0015031329821795225, 0.0019005683716386557, 0.0030600051395595074, -0.0013666240265592933, 0.0026548937894403934, 0.0017918114317581058, 0.001959707820788026, 0.0001708634663373232, 0.002737694652751088, -0.002339680213481188])
word1 = "అభి"
word2 = "రెండు గంటలు"
word3 = "పూర్తయింది"

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Telugu words and their embedding vectors
telugu_words = ['పదం', 'చిత్రం', 'వివరణ']
embedding_vectors = {
    'పదం': np.array([0.1, 0.2, 0.3]),
    'చిత్రం': np.array([0.4, 0.5, 0.6]),
    'వివరణ': np.array([0.7, 0.8, 0.9])
}

def find_missing_word(word1, word2):
    # Calculate the average embedding of the input words
    avg_embedding = (embedding_vectors[word1] + embedding_vectors[word2]) / 2
    
    # Calculate cosine similarity between the average embedding and all Telugu words
    similarities = {}
    for word in telugu_words:
        if word != word1 and word != word2:
            similarity = cosine_similarity([avg_embedding], [embedding_vectors[word]])[0][0]
            similarities[word] = similarity
    
    # Find the word with the highest cosine similarity
    missing_word = max(similarities, key=similarities.get)
    return missing_word, embedding_vectors[missing_word]

print("Enter any two Telugu words among పదం, చిత్రం, వివరణ:")
word1 = input("Enter the first word: ")
word2 = input("Enter the second word: ")

if word1 in telugu_words and word2 in telugu_words:
    missing_word, embedding_vector = find_missing_word(word1, word2)
    print("The missing word is:", missing_word)
    print("Its embedding vector is:", embedding_vector)
else:
    print("Invalid input! Please enter valid Telugu words.")
# Out:
# Enter any two Telugu words among పదం, చిత్రం, వివరణ:
# Enter the first word:  చిత్రం
# Enter the second word:  పదం
# The missing word is: వివరణ
# Its embedding vector is: [0.7 0.8 0.9]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

telugu_words = ["అభి", "రెండు గంటలు", "పూర్తయింది"]
embedding_vectors = {
074560582638, 0.0014297195011749864, -0.0012463477905839682, 0.002792725106701255, 0.0005113311344757676, -0.00241410662420094, 0.003144599497318268, 0.0025437374133616686, 0.0018310940358787775, -0.0022829484660178423, 0.0019408928928896785, 0.00133636430837214, 0.0017284564673900604, 0.0014186338521540165, 0.0006465848418883979, -0.001056720851920545, 0.0027846149168908596, 0.0032040600199252367, 0.0012642010115087032, -0.0009456650586798787, 2.3758411771268584e-06, 0.0004062727966811508, -0.0028194414917379618, -0.002741314936429262, -7.700522837694734e-05, 0.0004124291881453246, -0.0019144602119922638, -0.001575091271661222, -0.0024486915208399296, 0.002776205074042082, 4.0432612877339125e-05, -0.0015031329821795225, 0.0019005683716386557, 0.0030600051395595074, -0.0013666240265592933, 0.0026548937894403934, 0.0017918114317581058, 0.001959707820788026, 0.0001708634663373232, 0.002737694652751088, -0.002339680213481188])
}

def find_missing_word(word1, word2):
    # Calculate the average embedding of the input words
    avg_embedding = (embedding_vectors[word1] + embedding_vectors[word2]) / 2
    
    # Calculate cosine similarity between the average embedding and all Telugu words
    similarities = {}
    for word in telugu_words:
        if word != word1 and word != word2:
            similarity = cosine_similarity([avg_embedding], [embedding_vectors[word]])[0][0]
            similarities[word] = similarity
    
    # Find the word with the highest cosine similarity
    missing_word = max(similarities, key=similarities.get)
    return missing_word, embedding_vectors[missing_word]

print("Input any two Telugu words among 'అభి', 'రెండు గంటలు', 'పూర్తయింది'")
word1 = input("Word-1 : ")
word2 = input("Word-2 : ")

if word1 in telugu_words and word2 in telugu_words:
    missing_word, embedding_vector = find_missing_word(word1, word2)
    print("Missing word in the triplet is ", missing_word)
    print("Embedding vector : ", embedding_vector)
else:
    print("Invalid input!!\n\n(One or both of the inputted words not present)")
# Out:
# Input any two Telugu words among 'అభి', 'రెండు గంటలు', 'పూర్తయింది'
# Word-1 :  రెండు గంటలు
# Word-2 :  పూర్తయింది
# Missing word in the triplet is  అభి
# Embedding vector :  [ 2.71075731e-03 -1.48577814e-03 -3.56119068e-04  3.35454941e-04
#  -6.37046469e-05  3.82725790e-04  2.03795359e-03 -6.75718002e-06
#  -1.08198845e-03 -5.03576186e-04  1.96576631e-03  5.04700758e-04
#  -2.41420668e-04  3.11108236e-03 -1.64042786e-03 -2.79469881e-04
#   3.05847055e-03  2.24980921e-03  5.00952010e-04 -2.96085351e-03
#   3.82915343e-04 -7.62751908e-04  3.12274578e-03  4.03309270e-04
#   4.96687891e-04  8.02136667e-04 -6.12002215e-04 -1.66654470e-03
#   7.74764994e-05 -6.71393471e-04  2.20031105e-03  2.98004108e-03
#  -2.24918127e-04  9.92338290e-04 -2.03588489e-03  5.66441624e-04
#  -2.30874424e-03 -2.89800880e-03 -1.96673442e-03 -2.98549165e-03
#   2.42586504e-03 -1.92401046e-03  2.75878399e-03 -2.41451501e-03
#   1.14055828e-03  3.22499941e-03 -2.59514921e-03 -3.31501919e-03
# ...

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Define triplets with Telugu words representing subject, object, and relation
triplets = [
    {'subject': 'పదం', 'relation': 'చిత్రం', 'object': 'వివరణ'},
    {'subject': 'అభిప్రాయం', 'relation': 'రంగం', 'object': 'అర్థం'},
    {'subject': 'నిర్ణయం', 'relation': 'కథ', 'object': 'వ్యాఖ్య'}
]

# Embedding vectors for Telugu words
embedding_vectors = {
    'పదం': np.array([0.1, 0.2, 0.3]),
    'చిత్రం': np.array([0.4, 0.5, 0.6]),
    'వివరణ': np.array([0.7, 0.8, 0.9]),
    'అభిప్రాయం': np.array([0.2, 0.3, 0.4]),
    'రంగం': np.array([0.5, 0.6, 0.7]),
    'అర్థం': np.array([0.8, 0.9, 0.1]),
    'నిర్ణయం': np.array([0.3, 0.1, 0.2]),
    'కథ': np.array([0.6, 0.7, 0.8]),
    'వ్యాఖ్య': np.array([0.9, 0.1, 0.2])
    # Add more words and their embeddings as needed
}

def find_missing_word(word1, word2):
    # Calculate the average embedding of the input words
    avg_embedding = (embedding_vectors[word1] + embedding_vectors[word2]) / 2
    
    # Calculate cosine similarity between the average embedding and the third word in the triplet
    similarities = {}
    for triplet in triplets:
        if word1 in triplet.values() and word2 in triplet.values():
            for word in triplet.values():
                if word != word1 and word != word2:
                    similarity = cosine_similarity(avg_embedding.reshape(1, -1), embedding_vectors[word].reshape(1, -1))[0][0]
                    similarities[word] = similarity
    
    # Find the word with the highest cosine similarity
    missing_word = max(similarities, key=similarities.get)
    return missing_word, embedding_vectors[missing_word]

x = True
while x:
    print("\nInput any two Telugu words of your choice\n")
    word1 = input("Word-1 : ")
    word2 = input("Word-2 : ")
    
    try:
        if (word1 != word2):
            missing_word, embedding_vector = find_missing_word(word1, word2)
            print("Missing word in the triplet is ", missing_word)
            print("Embedding vector : ", embedding_vector)
        else:
            print("\nTwo inputted words are same..")
    except ValueError:
        print("\nNo triplet found containing both inputted words!!")

    c = input("\nWant to try another (y/n) : ").lower()
    while c not in ["y", "n"]:
        print("Invalid input! Please enter 'y' or 'n'.")
        c = input("\nWant to try another (y/n) : ").lower()

    if c == "y":
        x = True
    else:
        x = False
# Out:
# Input any two Telugu words of your choice
# Word-1 :  అభిప్రాయం
# Word-2 :  అర్థం
# Missing word in the triplet is  రంగం
# Embedding vector :  [0.5 0.6 0.7]
# Want to try another (y/n) :  v
# Invalid input! Please enter 'y' or 'n'.
# Want to try another (y/n) :  y
# Input any two Telugu words of your choice
# Word-1 :  పదం
# Word-2 :  చిత్రం
# Missing word in the triplet is  వివరణ
# Embedding vector :  [0.7 0.8 0.9]
# Want to try another (y/n) :  పదం
# Invalid input! Please enter 'y' or 'n'.
# Want to try another (y/n) :  y
# Input any two Telugu words of your choice
# Word-1 :  పదం
# Word-2 :  రంగం
# No triplet found containing both inputted words!!
# Want to try another (y/n) :  y
# Input any two Telugu words of your choice
# Word-1 :  రంగం
# Word-2 :  రంగం
# Two inputted words are same..
# Want to try another (y/n) :  y
# Input any two Telugu words of your choice
# Word-1 :  కథ
# Word-2 :  వ్యాఖ్య
# Missing word in the triplet is  నిర్ణయం
# Embedding vector :  [0.3 0.1 0.2]
# ...
